# %%
import pandas as pd

# %%
df=pd.read_json('22d13816-59fd-44d1-97dc-c98af92c480c_83d04ac6-cb74-4a96-a06a-e0d5442aa126_globalmart_data_from_0th_offset.json')

# %%
df
# Out:
#        id  sales_amt  qty  discount profit_amt  \
# 0    4102     2.0000    0    72.948       null
# 1    2698   261.9600    2     0.000    41.9136
# 2    6827   731.9400    3     0.000    219.582
# 3    8154    14.6200    2     0.000     6.8714
# 4    2624   957.5775    5     0.450   -383.031
# ..    ...        ...  ...       ...        ...
# 495   289   189.8820    3     0.400    -94.941
# 496   336   105.4200    2     0.000    51.6558
# 497  5569   119.6160    8     0.200    40.3704
# 498  8821   255.7600    4     0.000    81.8432
# 499  2898   241.5680    2     0.200    18.1176
#
#                                                  order  \
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...
# 1    {'order_id': 'CA-2014-145317', 'ship_mode': 'S...
# 2    {'order_id': 'CA-2016-118689', 'ship_mode': 'S...
# 3    {'order_id': 'CA-2017-140151', 'ship_mode': 'F...
# 4    {'order_id': 'CA-2017-127180', 'ship_mode': 'F...
# ..                                                 ...
# 495  {'order_id': 'CA-2016-112697', 'ship_mode': 'S...
# 496  {'order_id': 'CA-2015-137946', 'ship_mode': 'S...
# 497  {'order_id': 'CA-2017-157966', 'ship_mode': 'S...
# 498  {'order_id': 'CA-2017-100622', 'ship_mode': 'S...
# 499  {'order_id': 'US-2016-164630', 'ship_mode': 'S...
#
#                                                product
# 0    {'product_id': 'OFF-AP-10002684', 'product_nam...
# 1    {'product_id': 'FUR-BO-10001798', 'product_nam...
# 2    {'product_id': 'FUR-CH-10000454', 'product_nam...
# 3    {'product_id': 'OFF-LA-10000240', 'product_nam...
# 4    {'product_id': 'FUR-TA-10000577', 'product_nam...
# ..                                                 ...
# 495  {'product_id': 'FUR-TA-10001857', 'product_nam...
# 496  {'product_id': 'OFF-EN-10001434', 'product_nam...
# 497  {'product_id': 'OFF-BI-10002498', 'product_nam...
# 498  {'product_id': 'FUR-FU-10004864', 'product_nam...
# 499  {'product_id': 'FUR-CH-10002602', 'product_nam...
#
# [500 rows x 7 columns]

# %%
df['order'][0]
# Out:
# {'order_id': 'US-2017-102288',
#  'ship_mode': 'Standard Class',
#  'order_status': 'delivered',
#  'order_purchase_date': '2017-11-24 15:58:00',
#  'order_approved_at': '2017-11-28 03:18',
#  'order_delivered_carrier_date': '2017-12-01 19:09',
#  'order_delivered_customer_date': '2017-12-15 14:58',
#  'order_estimated_delivery_date': '2017-12-21',
#  'customer': {'customer_id': 'ZC-21910',
#   'customer_name': 'Zuschuss Carroll',
#   'segment': 'Consumer',
#   'contact_number': '+1 505-644-9222',
#   'address': {'zip_code': 92683,
#    'region': 'West',
#    'country': 'United States',
#    'city': 'westminster',
#    'state': 'california'}},
#  'vendor': {'VendorID': 'VEN04', 'Vendor Name': 'Johnsons Logistics'}}

# %%
df_sorted = df.sort_values(by='sales_amt', ascending=False)

# %%
df_sorted
# Out:
#        id  sales_amt  qty  discount profit_amt  \
# 166  2535   8159.952    8     0.400  -1359.992
# 354  7698   4355.168    4     0.200  1415.4296
# 319  8587   3991.980    2     0.000    1995.99
# 252  8563   3347.370   13     0.000   636.0003
# 28   7773   3083.430    7     0.500 -1665.0522
# ..    ...        ...  ...       ...        ...
# 0    4102      2.000    0    72.948       null
# 102  1439      1.788    3     0.800    -3.0396
# 62   1455      1.680    1     0.000       0.84
# 262  1831      1.624    2     0.800     -4.466
# 76   3984      1.248    3     0.800    -1.9344
#
#                                                  order  \
# 166  {'order_id': 'US-2017-117723', 'ship_mode': 'S...
# 354  {'order_id': 'CA-2017-151799', 'ship_mode': 'S...
# 319  {'order_id': 'CA-2017-162015', 'ship_mode': 'S...
# 252  {'order_id': 'CA-2016-123540', 'ship_mode': 'S...
# 28   {'order_id': 'CA-2016-108196', 'ship_mode': 'S...
# ..                                                 ...
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...
# 102  {'order_id': 'CA-2015-139731', 'ship_mode': 'S...
# 62   {'order_id': 'CA-2016-133711', 'ship_mode': 'F...
# 262  {'order_id': 'CA-2017-145884', 'ship_mode': 'S...
# 76   {'order_id': 'CA-2016-135265', 'ship_mode': 'S...
#
#                                                product
# 166  {'product_id': 'TEC-MA-10000822', 'product_nam...
# 354  {'product_id': 'OFF-BI-10004995', 'product_nam...
# 319  {'product_id': 'TEC-MA-10002927', 'product_nam...
# 252  {'product_id': 'TEC-AC-10003832', 'product_nam...
# 28   {'product_id': 'FUR-BO-10004834', 'product_nam...
# ..                                                 ...
# 0    {'product_id': 'OFF-AP-10002684', 'product_nam...
# 102  {'product_id': 'OFF-BI-10002609', 'product_nam...
# 62   {'product_id': 'OFF-AR-10001868', 'product_nam...
# 262  {'product_id': 'OFF-AP-10002203', 'product_nam...
# 76   {'product_id': 'OFF-BI-10004182', 'product_nam...
#
# [500 rows x 7 columns]

# %%
df_sorted['order'][0]['order_purchase_date']
# Out:
# '2017-11-24 15:58:00'

# %%
from datetime import datetime

# %%
dictionary_for_use={}
for i in range(df.shape[0]):
    key=datetime.strptime(df_sorted['order'][i]['order_purchase_date'], '%Y-%m-%d %H:%M:%S').month
    if key in dictionary_for_use:
        dictionary_for_use[key]+=df_sorted['sales_amt'][i]
    else:
        dictionary_for_use[key]=df_sorted['sales_amt'][i]

# %%
sorted_dict_sales = dict(sorted(dictionary_for_use.items(), key=lambda item: item[1]))
sorted_dict_sales
# Out:
# {9: 1320.4125000000004,
#  11: 3314.8160000000003,
#  4: 3878.7689999999993,
#  10: 5692.661500000001,
#  2: 8219.532000000001,
#  7: 9926.4818,
#  8: 10406.185,
#  12: 14170.78,
#  1: 16846.8305,
#  6: 17143.980799999998,
#  3: 17618.227000000003,
#  5: 20820.339999999997}

# %%
for i in range(df.shape[0]):
    if df['profit_amt'][i]=='null':
        df['profit_amt'][i]=0

# %%
dictionary_for_use_profit={}
for i in range(df.shape[0]):
    key=datetime.strptime(df['order'][i]['order_purchase_date'], '%Y-%m-%d %H:%M:%S').month
    if key in dictionary_for_use_profit:
        dictionary_for_use_profit[key]+=df['profit_amt'][i]
    else:
        dictionary_for_use_profit[key]=df['profit_amt'][i]
dictionary_for_use_profit
# Out:
# {11: 365.0811999999999,
#  7: -84.115,
#  5: -832.6444999999993,
#  2: 1329.5155,
#  1: 905.8689,
#  3: 5129.208399999999,
#  10: 1130.7502000000002,
#  4: -56.08249999999995,
#  12: -617.9494999999997,
#  6: -1297.0188999999998,
#  8: -350.64320000000004,
#  9: -281.3286}

# %%
sorted_dict_profit = dict(sorted(dictionary_for_use_profit.items(), key=lambda item: item[1]))
sorted_dict_profit
# Out:
# {6: -1297.0188999999998,
#  5: -832.6444999999993,
#  12: -617.9494999999997,
#  8: -350.64320000000004,
#  9: -281.3286,
#  7: -84.115,
#  4: -56.08249999999995,
#  11: 365.0811999999999,
#  1: 905.8689,
#  10: 1130.7502000000002,
#  2: 1329.5155,
#  3: 5129.208399999999}

# %%
count=0
for key1 in sorted_dict_profit:
    if sorted_dict_profit[key1]>0:
        count+=1
count
# Out:
# 5

# %%
temp_data=df[['order']]

# %%
temp_data
# Out:
#                                                  order
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...
# 1    {'order_id': 'CA-2014-145317', 'ship_mode': 'S...
# 2    {'order_id': 'CA-2016-118689', 'ship_mode': 'S...
# 3    {'order_id': 'CA-2017-140151', 'ship_mode': 'F...
# 4    {'order_id': 'CA-2017-127180', 'ship_mode': 'F...
# ..                                                 ...
# 495  {'order_id': 'CA-2016-112697', 'ship_mode': 'S...
# 496  {'order_id': 'CA-2015-137946', 'ship_mode': 'S...
# 497  {'order_id': 'CA-2017-157966', 'ship_mode': 'S...
# 498  {'order_id': 'CA-2017-100622', 'ship_mode': 'S...
# 499  {'order_id': 'US-2016-164630', 'ship_mode': 'S...
#
# [500 rows x 1 columns]

# %%
temp_data['order_delivered']=0
temp_data['order_expected']=0
for i in range(df.shape[0]):
    temp_data['order_delivered'][i]=temp_data['order'][i]['order_delivered_customer_date']
    temp_data['order_expected'][i]=temp_data['order'][i]['order_estimated_delivery_date']
# Out:
# C:\Users\shivam.thakur\AppData\Local\Temp\ipykernel_28484\3481799429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['order_delivered']=0
# C:\Users\shivam.thakur\AppData\Local\Temp\ipykernel_28484\3481799429.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['order_expected']=0
# C:\Users\shivam.thakur\AppData\Local\Temp\ipykernel_28484\3481799429.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['order_delivered'][i]=temp_data['order'][i]['order_delivered_customer_date']
# C:\Users\shivam.thakur\AppData\Local\Temp\ipykernel_28484\3481799429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['order_expected'][i]=temp_data['order'][i]['order_estimated_delivery_date']

# %%
for i in range(temp_data.shape[0]):
    
    datetime_obj = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')

# Format the datetime object as a date string
    temp_data['order_delivered'][i] = datetime_obj.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 for i in range(temp_data.shape[0]):
# ----> 3     datetime_obj = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')
#       5 # Format the datetime object as a date string
#       6     temp_data['order_delivered'][i] = datetime_obj.strftime('%Y-%m-%d')
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2017-12-15' does not match format '%Y-%m-%d %H:%M'

# %%
temp_data
# Out:
#                                                  order   order_delivered  \
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...        2017-12-15
# 1    {'order_id': 'CA-2014-145317', 'ship_mode': 'S...        2018-07-24
# 2    {'order_id': 'CA-2016-118689', 'ship_mode': 'S...        2018-06-04
# 3    {'order_id': 'CA-2017-140151', 'ship_mode': 'F...        2018-04-03
# 4    {'order_id': 'CA-2017-127180', 'ship_mode': 'F...        2018-01-30
# ..                                                 ...               ...
# 495  {'order_id': 'CA-2016-112697', 'ship_mode': 'S...  2018-06-25 22:05
# 496  {'order_id': 'CA-2015-137946', 'ship_mode': 'S...  2018-03-26 20:57
# 497  {'order_id': 'CA-2017-157966', 'ship_mode': 'S...  2018-03-23 17:53
# 498  {'order_id': 'CA-2017-100622', 'ship_mode': 'S...  2018-03-21 22:03
# 499  {'order_id': 'US-2016-164630', 'ship_mode': 'S...  2018-03-17 15:26
#
#     order_expected
# 0       2017-12-21
# 1       2018-07-27
# 2       2018-06-18
# 3       2018-03-28
# 4       2018-02-07
# ..             ...
# 495     2018-07-18
# 496     2018-04-11
# 497     2018-04-13
# 498     2018-03-28
# 499     2018-03-27
#
# [500 rows x 3 columns]

# %%
temp_data=temp_data.reset_index(drop=True)

# %%
for i in range(temp_data.shape[0]):
    
    datetime_obj = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')

# Format the datetime object as a date string
    temp_data['order_delivered'][i] = datetime_obj.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 for i in range(temp_data.shape[0]):
# ----> 3     datetime_obj = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')
#       5 # Format the datetime object as a date string
#       6     temp_data['order_delivered'][i] = datetime_obj.strftime('%Y-%m-%d')
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2017-12-15' does not match format '%Y-%m-%d %H:%M'

# %%
for i in range(temp_data.shape[0]):
    # Parse the date string using the current format
    if len(temp_data['order_delivered'][i]) > 10:
        date = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')
    else:
        date = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d')
    
    # Format the date as 'YYYY-MM-DD'
    formatted_date = date.strftime('%Y-%m-%d')
    
    # Append the formatted date to the list
    temp_data['order_delivered'][i]=formatted_date
# Out:
# C:\Users\shivam.thakur\AppData\Local\Temp\ipykernel_28484\4197181053.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_data['order_delivered'][i]=formatted_date
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 6
#       4     date = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d %H:%M')
#       5 else:
# ----> 6     date = datetime.strptime(temp_data['order_delivered'][i], '%Y-%m-%d')
#       8 # Format the date as 'YYYY-MM-DD'
#       9 formatted_date = date.strftime('%Y-%m-%d')
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\anaconda3\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data 'null' does not match format '%Y-%m-%d'

# %%
temp_data
# Out:
#                                                  order   order_delivered  \
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...        2017-12-15
# 1    {'order_id': 'CA-2014-145317', 'ship_mode': 'S...        2018-07-24
# 2    {'order_id': 'CA-2016-118689', 'ship_mode': 'S...        2018-06-04
# 3    {'order_id': 'CA-2017-140151', 'ship_mode': 'F...        2018-04-03
# 4    {'order_id': 'CA-2017-127180', 'ship_mode': 'F...        2018-01-30
# ..                                                 ...               ...
# 495  {'order_id': 'CA-2016-112697', 'ship_mode': 'S...  2018-06-25 22:05
# 496  {'order_id': 'CA-2015-137946', 'ship_mode': 'S...  2018-03-26 20:57
# 497  {'order_id': 'CA-2017-157966', 'ship_mode': 'S...  2018-03-23 17:53
# 498  {'order_id': 'CA-2017-100622', 'ship_mode': 'S...  2018-03-21 22:03
# 499  {'order_id': 'US-2016-164630', 'ship_mode': 'S...  2018-03-17 15:26
#
#     order_expected
# 0       2017-12-21
# 1       2018-07-27
# 2       2018-06-18
# 3       2018-03-28
# 4       2018-02-07
# ..             ...
# 495     2018-07-18
# 496     2018-04-11
# 497     2018-04-13
# 498     2018-03-28
# 499     2018-03-27
#
# [500 rows x 3 columns]

# %%
temp_data[['order_delivered','order_expected']]
# Out:
#       order_delivered order_expected
# 0          2017-12-15     2017-12-21
# 1          2018-07-24     2018-07-27
# 2          2018-06-04     2018-06-18
# 3          2018-04-03     2018-03-28
# 4          2018-01-30     2018-02-07
# ..                ...            ...
# 495  2018-06-25 22:05     2018-07-18
# 496  2018-03-26 20:57     2018-04-11
# 497  2018-03-23 17:53     2018-04-13
# 498  2018-03-21 22:03     2018-03-28
# 499  2018-03-17 15:26     2018-03-27
#
# [500 rows x 2 columns]

# %%
type(temp_data['order_delivered'][0])
# Out:
# str

# %%
import pandas as pd


data = {'order_delivered': temp_data['order_delivered'].tolist(),
        'order_expected': temp_data['order_expected'].tolist()}
df = pd.DataFrame(data)

df['order_delivered'] = pd.to_datetime(df['order_delivered'])
df['order_expected'] = pd.to_datetime(df['order_expected'])

df['date_difference'] = (df['order_delivered'] - df['order_expected']).dt.days
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: null
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "null" at position 20
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[29], line 8
#       4 data = {'order_delivered': temp_data['order_delivered'].tolist(),
#       5         'order_expected': temp_data['order_expected'].tolist()}
#       6 df = pd.DataFrame(data)
# ----> 8 df['order_delivered'] = pd.to_datetime(df['order_delivered'])
#       9 df['order_expected'] = pd.to_datetime(df['order_expected'])
#      11 df['date_difference'] = (df['order_delivered'] - df['order_expected']).dt.days
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: null present at position 20

# %%
df
# Out:
#       order_delivered order_expected
# 0          2017-12-15     2017-12-21
# 1          2018-07-24     2018-07-27
# 2          2018-06-04     2018-06-18
# 3          2018-04-03     2018-03-28
# 4          2018-01-30     2018-02-07
# ..                ...            ...
# 495  2018-06-25 22:05     2018-07-18
# 496  2018-03-26 20:57     2018-04-11
# 497  2018-03-23 17:53     2018-04-13
# 498  2018-03-21 22:03     2018-03-28
# 499  2018-03-17 15:26     2018-03-27
#
# [500 rows x 2 columns]

# %%
temp_data['date_difference']=df['date_difference']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_difference'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 temp_data['date_difference']=df['date_difference']
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'date_difference'

# %%
d=0
for i in range(temp_data.shape[0]):
    if temp_data['date_difference'][i]>0:
        d+=1
        
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_difference'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 d=0
#       2 for i in range(temp_data.shape[0]):
# ----> 3     if temp_data['date_difference'][i]>0:
#       4         d+=1
#       6 d
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'date_difference'
