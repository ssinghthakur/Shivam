# %%
import json

# %%
with open('22d13816-59fd-44d1-97dc-c98af92c480c_83d04ac6-cb74-4a96-a06a-e0d5442aa126_globalmart_data_from_0th_offset.json','r') as globalmart:
    data = json.load(globalmart)

# %%
data
# Out:
# [{'id': 4102,
#   'sales_amt': 2.0,
#   'qty': 0,
#   'discount': 72.948,
#   'profit_amt': 'null',
#   'order': {'order_id': 'US-2017-102288',
#    'ship_mode': 'Standard Class',
#    'order_status': 'delivered',
#    'order_purchase_date': '2017-11-24 15:58:00',
#    'order_approved_at': '2017-11-28 03:18',
#    'order_delivered_carrier_date': '2017-12-01 19:09',
#    'order_delivered_customer_date': '2017-12-15 14:58',
#    'order_estimated_delivery_date': '2017-12-21',
#    'customer': {'customer_id': 'ZC-21910',
#     'customer_name': 'Zuschuss Carroll',
#     'segment': 'Consumer',
#     'contact_number': '+1 505-644-9222',
#     'address': {'zip_code': 92683,
#      'region': 'West',
#      'country': 'United States',
#      'city': 'westminster',
#      'state': 'california'}},
#    'vendor': {'VendorID': 'VEN04', 'Vendor Name': 'Johnsons Logistics'}},
#   'product': {'product_id': 'OFF-AP-10002684',
# ...

# %%
import pandas as pd

# %%
data = pd.read_json('22d13816-59fd-44d1-97dc-c98af92c480c_83d04ac6-cb74-4a96-a06a-e0d5442aa126_globalmart_data_from_0th_offset.json')

# %%
def functioni(dataframe,name_of_product):
#     product_name=dataframe['product'][product_name]
    index=0
    for i in range(dataframe.shape[0]):
        if dataframe['product'][i]['product_name']==name_of_product:
            index=i
            break
    
    sizes1=[]  
         
    sizes1=dataframe['product'][index]['sizes'].split(',')
    return sizes1

# %%
functioni(data,'Mitel 5320 IP Phone VoIP phone.')
# Out:
# ['7']

# %%
data
# Out:
#        id  sales_amt  qty  discount profit_amt  \
# 0    4102     2.0000    0    72.948       null
# 1    2698   261.9600    2     0.000    41.9136
# 2    6827   731.9400    3     0.000    219.582
# 3    8154    14.6200    2     0.000     6.8714
# 4    2624   957.5775    5     0.450   -383.031
# ..    ...        ...  ...       ...        ...
# 495   289   189.8820    3     0.400    -94.941
# 496   336   105.4200    2     0.000    51.6558
# 497  5569   119.6160    8     0.200    40.3704
# 498  8821   255.7600    4     0.000    81.8432
# 499  2898   241.5680    2     0.200    18.1176
#
#                                                  order  \
# 0    {'order_id': 'US-2017-102288', 'ship_mode': 'S...
# 1    {'order_id': 'CA-2014-145317', 'ship_mode': 'S...
# 2    {'order_id': 'CA-2016-118689', 'ship_mode': 'S...
# 3    {'order_id': 'CA-2017-140151', 'ship_mode': 'F...
# 4    {'order_id': 'CA-2017-127180', 'ship_mode': 'F...
# ..                                                 ...
# ...

# %%
empty_list=[]
for name in data['product']:
    product_name=name['product_name']
    sizes1=len(name['sizes'].split(','))
    empty_list.append([product_name,sizes1])

# %%
empty_list
# Out:
# [['Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone Line Protection',
#   1],
#  ['Bush Somerset Collection Bookcase', 1],
#  ['Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 5],
#  ['Self-Adhesive Address Labels for Typewriters by Universal', 1],
#  ['Bretford CR4500 Series Slim Rectangular Table', 5],
#  ["Eldon Fold 'N Roll Cart System", 1],
#  ['Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 1],
#  ['Newell 322', 1],
#  ['Mitel 5320 IP Phone VoIP phone', 1],
#  ['DXL Angle-View Binders with Locking Rings by Samsill', 1],
#  ['Belkin F5C206VTEL 6 Outlet Surge', 1],
#  ['Chromcraft Rectangular Conference Tables', 1],
#  ['Konftel 250 Conference\xa0phone\xa0- Charcoal black', 1],
#  ['Xerox 1967', 1],
#  ['Fellowes PB200 Plastic Comb Binding Machine', 1],
#  ['Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter',
#   1],
#  ['Storex DuraTech Recycled Plastic Frosted Binders', 1],
# ...

# %%
maxi=0
namei=""
for temp in empty_list:
    if temp[1]>maxi:
        maxi=temp[1]
        namei=temp[0]

# %%
namei
# Out:
# 'Redi-Strip #10 Envelopes, 4 1/8 x 9 1/2'
